# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

df_original['job_posted_date'] = pd.to_datetime(df_original['job_posted_date'])

# %%
df_altered = df_original.copy()

# %%
print('ID of df_original:', id(df_original))
print('ID of df_altered:', id(df_altered))
print('Are the two dataframes the same?', id(df_original) == id(df_altered))
# Out:
# ID of df_original: 2689107226448
# ID of df_altered: 2689108223184
# Are the two dataframes the same? False

# %%
median_salary = df_altered['salary_year_avg'].median()
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)
df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
df_original.loc[:5, 'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
df_altered.sample(5)
# Out:
#        job_title_short                      job_title  \
# 361975   Data Engineer                  Data Engineer
# 401574    Data Analyst       Data Analyst- Purchasing
# 280615   Data Engineer  Data Engineer II - Now Hiring
# 114790  Data Scientist            Lead Data Scientist
# 728334   Data Engineer       Mid/Senior Data Engineer
#
#                         job_location               job_via job_schedule_type  \
# 361975                    London, UK  via Jobs Trabajo.org         Full-time
# 401574                Morgantown, PA          via LinkedIn         Full-time
# 280615                   Madison, WI          via Snagajob         Full-time
# 114790  Jagatsinghpur, Odisha, India      via Talents Jobs         Full-time
# 728334                      Anywhere          via LinkedIn         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 361975               False           United Kingdom 2023-01-18 23:16:53
# 401574               False  New York, United States 2023-02-13 18:00:25
# 280615               False                    Sudan 2023-02-03 08:07:44
# 114790               False                    India 2023-12-05 08:11:04
# 728334                True                   Brazil 2023-11-22 21:12:38
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 361975                   True                 False  United Kingdom
# 401574                   True                  True   United States
# 280615                   True                 False           Sudan
# 114790                  False                 False           India
# 728334                   True                 False          Brazil
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 361975        None         115000.0              NaN
# 401574        None         115000.0              NaN
# 280615        None         115000.0              NaN
# 114790        None         115000.0              NaN
# 728334        None         115000.0              NaN
#
#                             company_name  \
# 361975                        Blockchain
# 401574                 Morgan Truck Body
# 280615                       Robert Half
# 114790  Education and Training Cognizant
# 728334                             Belvo
#
#                                                job_skills  \
# 361975                                            ['sql']
# 401574                           ['excel', 'spreadsheet']
# 280615                 ['azure', 'snowflake', 'power bi']
# 114790                                               None
# 728334  ['go', 'scala', 'python', 'javascript', 'sass'...
#
#                                           job_type_skills
# 361975                           {'programming': ['sql']}
# 401574        {'analyst_tools': ['excel', 'spreadsheet']}
# 280615  {'analyst_tools': ['power bi'], 'cloud': ['azu...
# 114790                                               None
# 728334  {'cloud': ['aws', 'redshift'], 'libraries': ['...

# %%
df_altered.sample(5, random_state=42)
# Out:
#               job_title_short  \
# 502901   Senior Data Engineer
# 406337  Senior Data Scientist
# 659951          Data Engineer
# 541593           Data Analyst
# 425158   Senior Data Engineer
#
#                                                 job_title  \
# 502901                               Senior Data Engineer
# 406337                          Senior Analytics Engineer
# 659951                                      Data Engineer
# 541593                                       Data Analyst
# 425158  Senior Data Engineer. Job in Amsterdam NBC4i Jobs
#
#                    job_location          job_via job_schedule_type  \
# 502901              St Paul, MN        via BeBee         Full-time
# 406337               London, UK     via LinkedIn         Full-time
# 659951  Newcastle upon Tyne, UK       via Indeed         Full-time
# 541593                    Malta  via Trabajo.org         Full-time
# 425158   Amsterdam, Netherlands   via NBC4i Jobs         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 502901               False  Florida, United States 2023-12-17 11:09:06
# 406337               False          United Kingdom 2023-10-06 16:09:56
# 659951               False          United Kingdom 2023-09-06 10:11:25
# 541593               False                   Malta 2023-02-14 21:14:18
# 425158               False             Netherlands 2023-06-19 16:34:30
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 502901                  False                 False   United States
# 406337                  False                 False  United Kingdom
# 659951                   True                 False  United Kingdom
# 541593                   True                 False           Malta
# 425158                   True                 False     Netherlands
#
#        salary_rate  salary_year_avg  salary_hour_avg            company_name  \
# 502901        None         115000.0              NaN           ManpowerGroup
# 406337        None         115000.0              NaN                 Harnham
# 659951        None         115000.0              NaN             Morgan King
# 541593        None         115000.0              NaN                 Konnekt
# 425158        None         115000.0              NaN  Independent Recruiters
#
#                                                job_skills  \
# 502901                            ['sql', 'azure', 'git']
# 406337  ['sql', 'python', 'bigquery', 'snowflake', 'lo...
# 659951                                               None
# 541593                                           ['jira']
# 425158                                         ['python']
#
#                                           job_type_skills
# 502901  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 406337  {'analyst_tools': ['looker'], 'cloud': ['bigqu...
# 659951                                               None
# 541593                                {'async': ['jira']}
# 425158                        {'programming': ['python']}
