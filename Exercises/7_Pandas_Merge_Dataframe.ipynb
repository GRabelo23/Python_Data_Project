# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_us = df[df['job_country'] == 'United States'].copy()
df_us['job_posted_month'] = df_us['job_posted_date'].dt.strftime('%B')
df_us.drop_duplicates(subset=['job_title','company_name'], inplace=True)
df_us_job_count = df_us.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')
df_us_job_count.reset_index(inplace=True)
df_us_job_count['month_number'] = pd.to_datetime(df_us_job_count['job_posted_month'], format='%B').dt.month
df_us_job_count.sort_values(by='month_number', inplace=True)
df_us_job_count.set_index('job_posted_month', inplace=True)
df_us_job_count.drop(columns='month_number', inplace=True)
df_us_job_count
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        447              30          5250
# February                       357              20          3679
# March                          366              19          3764
# April                          486              36          3607
# May                            243              18          2865
# June                           380              30          3374
# July                           493              36          3268
# August                         769              35          4130
# September                      807              46          3202
# October                        816              41          3676
# November                       629              34          2994
# December                       567              40          2838
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_software = pd.read_csv("https://lukeb.co/software_csv",index_col='job_posted_month')
df_software
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# ...

# %%
df_us_job_count_merged = df_us_job_count.merge(df_software, on="job_posted_month")
df_us_job_count_merged
# Out:
#                   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        447              30          5250
# February                       357              20          3679
# March                          366              19          3764
# April                          486              36          3607
# May                            243              18          2865
# June                           380              30          3374
# July                           493              36          3268
# August                         769              35          4130
# September                      807              46          3202
# October                        816              41          3676
# November                       629              34          2994
# December                       567              40          2838
#
#                   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
top_5 = df_us_job_count_merged.sum().sort_values(ascending=False).head(5).index
top_5 = top_5.to_list()
top_5
# Out:
# ['Front-End Developer',
#  'Back-End Developer',
#  'Full-Stack Developer',
#  'UI/UX Designer',
#  'Data Analyst']

# %%
df_us_job_count_merged[top_5].plot(kind='line')
plt.xlabel('')
plt.ylabel('Job Postings')
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.1), ncol=3)
plt.tight_layout()
plt.title('Monthly Job Postings for Top Tech Jobs in the US - 2023')
plt.show()
